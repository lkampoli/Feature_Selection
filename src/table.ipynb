# %%
import pandas as pd

# %%
df = pd.read_csv("C:/Users/user/Feature_Selection/data/STS/transport/boltzmann/corr_df.csv", sep=",", header=0, index_col='index')
df.head()
# Out:
#              Conductivity
# index
# Pressure        -0.000290
# Temperature      0.970970
# X1              -0.603050
# X2               0.257686
# X3               0.461838

# %%
df = pd.read_csv("C:/Users/user/Feature_Selection/data/STS/transport/boltzmann/corr_df.csv", sep=",", header=0, index_col='index')
df.head()
# Out:
#              Conductivity
# index
# Pressure        -0.000290
# Temperature      0.970970
# X1              -0.603050
# X2               0.257686
# X3               0.461838

# %%
pd.concat([df,df ], axis=1)
# Out:
#               Conductivity  Conductivity
# index
# Pressure         -0.000290     -0.000290
# Temperature       0.970970      0.970970
# X1               -0.603050     -0.603050
# X2                0.257686      0.257686
# X3                0.461838      0.461838
# X4                0.536302      0.536302
# X5                0.565952      0.565952
# X6                0.576514      0.576514
# X7                0.577931      0.577931
# X8                0.574671      0.574671
# X9                0.568957      0.568957
# X10               0.561971      0.561971
# X11               0.554376      0.554376
# X12               0.546554      0.546554
# X13               0.538731      0.538731
# X14               0.531038      0.531038
# X15               0.523554      0.523554
# X16               0.516323      0.516323
# X17               0.509366      0.509366
# X18               0.502692      0.502692
# X19               0.496302      0.496302
# X20               0.490192      0.490192
# ...
